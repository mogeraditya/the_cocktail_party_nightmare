# %% [markdown]
# # Report
# ### Written on 8th Jul 2025; Aditya Moger
#
# ____
#
# This notebook_consists a summary of the work done from 2nd June 25 to 20th of June 25. Involves changes made to the cocktail_party_ngihtmare github repo by Thejasvi.
#
# _Main topics covered :_
# - Adjusting files in the repo and changing code to make it python3 compatible
# - Changes in focal bat position and heading vectors (in more detail later)
# - Changing focal bat selection method; moving from proportion of max radius to multiples of minimum inter bat spacing
# - Changing existing code to generate new plots of our data now with different parameters
# - Debugging errors; specifically divide by zero and directional azimuth
